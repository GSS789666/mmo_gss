# %%
# подключение библиотек
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt
import re  
import random

#ввод набор данных
url="ds.salaries.csv"
dataset=pd.read_csv(url)
dataset
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %% [markdown]
# # 新段落

# %%
uniq_year = d.drop_duplicates(subset=["work_year"])
uniq_year["work_year"]
# Out:
# 1      2020
# 74     2021
# 290    2022
# Name: work_year, dtype: int64

# %%
dataset1=dataset[dataset["experience_level"]=="MI"]
dataset1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 3             3       2020               MI              FT
# 7             7       2020               MI              FT
# 8             8       2020               MI              FT
# 11           11       2020               MI              FT
# ..          ...        ...              ...             ...
# 567         567       2022               MI              FT
# 586         586       2022               MI              FT
# 598         598       2022               MI              FT
# 599         599       2022               MI              FT
# 606         606       2022               MI              FT
#
#                  job_title    salary salary_currency  salary_in_usd  \
# 0           Data Scientist     70000             EUR          79833
# 3     Product Data Analyst     20000             USD          20000
# ...

# %%
dataset1.groupby("remote_ratio").salary_in_usd.mean().plot()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")

sns.boxplot(x=dataset1["work_year"], y=dataset1["salary_in_usd"])
plt.show()

# %%
# libraries & dataset
import seaborn as sns
import matplotlib.pyplot as plt
# set a grey background (use sns.set_theme() if seaborn version 0.11.0 or above) 
sns.set(style="darkgrid")
df = dataset1
 
# plot
sns.violinplot( x=df["work_year"], y=df["salary_in_usd"] )
plt.show()

# %%
sns.pairplot(dataset)
plt.show()

# %%
dataset2=pd.DataFrame(dataset, columns=['work_year','salary_in_usd','remote_ratio'])
dataset2 = dataset2[dataset2["salary_in_usd"] > 200000]
dataset2
# Out:
#      work_year  salary_in_usd  remote_ratio
# 1         2020         260000             0
# 25        2020         325000           100
# 33        2020         450000             0
# 37        2020         250000            50
# 63        2020         412000           100
# 74        2021         235000           100
# 78        2021         270000           100
# 93        2021         276000             0
# 97        2021         450000           100
# 115       2021         225000           100
# 138       2021         220000             0
# 141       2021         240000             0
# 157       2021         423000            50
# 160       2021         230000            50
# 167       2021         250000             0
# 173       2021         235000           100
# 224       2021         225000           100
# 225       2021         416000           100
# 231       2021         256000           100
# 252       2021         600000           100
# ...

# %%
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

d = dataset2.set_index('remote_ratio')
 
# Calculate the distance between each sample
Z = linkage(dataset2, 'ward')
# Plot with Custom leaves
dendrogram(Z,labels=d.index)

# Show the graph
plt.show()
